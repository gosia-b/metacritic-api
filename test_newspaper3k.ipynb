# %%
from pprint import pprint

import newspaper
import pandas as pd

# %% [markdown]
# # Newspaper3k - info
# [docs](https://newspaper.readthedocs.io/en/latest/)
# [quickstart](https://newspaper.readthedocs.io/en/latest/user_guide/quickstart.html)
# [advanced](https://newspaper.readthedocs.io/en/latest/user_guide/advanced.html)
# (e.g. quickly download articles concurrently with multi-threading)
#
# [pypi](https://pypi.org/project/newspaper3k/)
# [github](https://github.com/codelucas/newspaper)

# %%
help(newspaper)
# Out:
# Help on package newspaper:
#
# NAME
#     newspaper - Wherever smart people work, doors are unlocked. -- Steve Wozniak
#
# PACKAGE CONTENTS
#     api
#     article
#     cleaners
#     configuration
#     extractors
#     images
#     mthreading
#     network
#     nlp
#     outputformatters
#     parsers
#     settings
#     source
#     text
#     urls
#     utils
#     version
#     videos (package)
#
# DATA
#     __copyright__ = 'Copyright 2014, Lucas Ou-Yang'
#     __license__ = 'MIT'
#     __title__ = 'newspaper'
#     news_pool = <newspaper.mthreading.NewsPool object>
#
# VERSION
#     0.2.8
#
# AUTHOR
#     Lucas Ou-Yang
#
# FILE
#     c:\users\gosia\anaconda3\lib\site-packages\newspaper\__init__.py

# %% [markdown]
# # Scraping single article

# %%
from newspaper import Article

# %% [markdown]
# ### Download

# %%
url = 'https://www.hookedgamers.com/pc/forspoken/review/article-2402.html'
article = Article(url, keep_article_html=True)
article.download()
print(article.html)
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="https://www.w3.org/1999/xhtml">
# <head>
#  	<meta http-equiv="Content-Type" content="text/html; charset=utf-8">
# 	<meta property="fb:app_id" content="337785116266465"/>
#     <meta name="viewport" content="width=device-width" />
#     <meta name="application-name" content="Hooked Gamers" />
#     <meta name="description" content="We played Forspoken - It frequently is so bad, it's almost good. Awful optimization, cringeworthy dialogue, forgettable narrative, and mediocre gameplay">
#     <meta name="keywords" content="Forspoken, Action-Adventure game, Square Enix, Luminous Productions" />
# 	<title>Forspoken PC review - "Forspoken should be forgotten" | Hooked Gamers</title>
# 	<meta property="og:image" content="https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg" />
# 	<meta property="og:image:type" content="image/jpeg" />
#
# 	<meta property="fb:app_id"       content="337785116266465" />
# 	<link href='//fonts.googleapis.com/css?family=Open+Sans:400,800,700,400italic,700italic,800italic' rel='stylesheet' type='text/css'>
#     <link rel="stylesheet" href="/_inc/style.css" />
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-563957-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
#
# <script type='text/javascript'>
# var googletag = googletag || {};
# googletag.cmd = googletag.cmd || [];
# (function() {
# var gads = document.createElement('script');
# gads.async = true;
# gads.type = 'text/javascript';
# var useSSL = 'https:' == document.location.protocol;
# gads.src = (useSSL ? 'https:' : 'http:') +
# '//www.googletagservices.com/tag/js/gpt.js';
# var node = document.getElementsByTagName('script')[0];
# node.parentNode.insertBefore(gads, node);
# })();
# </script>
#
# </head>
# <body>
# <div id="fb-root"></div>
# <script>(function(d, s, id) {
#   var js, fjs = d.getElementsByTagName(s)[0];
#   if (d.getElementById(id)) return;
#   js = d.createElement(s); js.id = id;
#   js.src = "//connect.facebook.net/en_US/sdk.js#xfbml=1&appId=337785116266465&version=v2.0";
#   fjs.parentNode.insertBefore(js, fjs);
# }(document, 'script', 'facebook-jssdk'));</script>
#
# <nav id="main-navigation">
# <section class="nav">
# 	<div class="top">
# 		<div class="logo">
# 			<a href="/"><img src="/_inc/im/hookedgamers.png"></a>
# 		</div>
# 		<div class="side">
# 			<img src="/_inc/im/nav_background_small.png">
#
# 			<nav class="navTop">
# 				<ul>
# 					<li class="firstNav"><a href="/previews.html"><h3>EARLY ACCESS SCOUT</h3>
# 					Latest Steam Previews</a></li>
# 					<!-- li class="firstNav"><a href="/content/specials/game_of_the_year_2017/"><h3>GAME OF THE YEAR 2017</h3>
# 					The votes are in!</a></li -->
# 				</ul>
# 			</nav>
#
# 			<nav class="navBottom" style="z-index: 10;">
# 				<div>
# 					<form method="post" action="/search/">
# 						<input type="hidden" class="searchVal" value="true" name="search">
# 						<input type="search" class="searchFld" placeholder="find a game" name="gametitle">
# 						<input type="submit" class="searchBtn" value="">
# 					</form>
# 				</div>
# 				<ul>
# 					<li><a title="hooked gamers home" href="/" >Home</a></li>
# 					<li><a title="latest reviews" href="/reviews.html"  class="active">Reviews</a></li>
# 					<li><a title="latest previews" href="/previews.html" >Previews</a></li>
# 					<li><a title="specials and features" href="/features.html" >Features</a></li>
# 					<li><a title="new cheats" href="/cheats.html" >Cheats</a></li>
# 					<li><a title="upcoming games" href="/upcoming_games.html" >Releases</a></li>
# 					<li><a title="new screenshots" href="/screenshots.html" >screens</a></li>
# 					<li class="icon searchBox"><a href="#" class="search" title="search"><i class="fa fa-search"></i></a></li>
# 					<li class="icon"><a target="blank" href="https://steamcommunity.com/groups/hookedgamers#curation" title="visit our Steam page"><i class="fa fa-steam"></i></a></li>
# 					<li class="icon"><a target="blank" title="like us on Facebook" href="https://www.facebook.com/hookedgamers"><i class="fa fa-facebook"></i></a></li>
# 					<li class="icon"><a target="blank" title="follow us on Twitter" href="https://twitter.com/HookedGamers"><i class="fa fa-twitter"></i></a></li>
# 				</ul>
# 			</nav>
# 		</div>
#
# 		<div class="mobile-nav">
# 			 <div class="menu-btn" id="menu-btn">
# 				<i class="fa fa-bars"></i>
# 			 </div>
#
# 			 <div class="responsive-menu">
# 				<ul>
# 					<li><a title="latest reviews" href="/reviews.html"  class="active">Reviews</a></li>
# 					<li><a title="latest previews" href="/previews.html" >Previews</a></li>
# 					<li><a title="specials and features" href="/features.html" >Features</a></li>
# 					<li><a title="new cheats" href="/cheats.html" >Cheats</a></li>
# 					<li><a title="upcoming games" href="/upcoming_games.html" >Releases</a></li>
# 					<li><a title="new screenshots" href="/screenshots.html" >Screens</a></li>
# 					<li><a target="blank" title="follow us on Twitter" href="https://twitter.com/HookedGamers">Twitter</a></li>
# 					<li><a target="blank" title="like us on Facebook" href="https://www.facebook.com/hookedgamers">Facebook</a></li>
# 					<li><a target="blank" href="https://steamcommunity.com/groups/hookedgamers#curation" title="visit our Steam page">Steam</a></li>
# 					<li><a title="search" href="/search/">Search</a></li>
# 				</ul>
# 			 </div>
# 		</div>
#
# 	</div>
# </section>
# </nav>
#
# <section class="wrapper">
#
# 	<div class="topAd">
# 					<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 			<!-- full-width top -->
# 			<ins class="adsbygoogle"
# 				 style="display:block"
# 				 data-ad-client="ca-pub-0020849830068151"
# 				 data-ad-slot="7705602205"
# 				 data-ad-format="auto"></ins>
# 			<script>
# 			(adsbygoogle = window.adsbygoogle || []).push({});
# 			</script>
# 	</div>
# 	<article class="content">
# 		<header class="block">
# 			<div class="gameTitle">
# 				<h1>Forspoken</h1>
# 				<div><p><a href="/pc/forspoken.html" title="Overview of Forspoken"><font>More</font><span> info</span> &raquo</a></p></div>
# 			</div>
# 			<img src="/images/7017/forspoken/reviews/header_2402_forspoken.jpg" alt="Forspoken review" class="header" />
# 			<div>
# 				<a href="/blogs/danlenois/overview.html">
#
#
# 						<img src="/_nhg/base/im/contact/avatar_danlenois.jpg" alt="Dan Lenois" title="Dan Lenois">
#
#
# 				</a>
# 				<h3>Review</h3>
# 				<h2>Forspoken should be forgotten</h2>
# 			</div>
# 		</header>
#
# 		<div class="articleInfo">
# 			<time><span itemprop="dtreviewed" datetime="2023-02-15">February 15th, 2023</span></time> by <a itemprop="reviewer" href="/blogs/danlenois/overview.html">Dan Lenois</a>
# 			<div><font>reviewed on </font><span>PC</span></div>
# 		</div>
#
#
# 	<section class="article" itemscope itemtype="http://data-vocabulary.org/Review">
#
#
# 				<h2>Aims low, lands lower.</h2><br />
# Under the mire of <i>Forspoken</i>&#039;s many flaws, there is the individual fragments of what could have been a highly compelling, or at least passable, narrative. <i>Forspoken</i> follows the character of Frey, who grew up with no family, no prospects, and forced to rely on street gangs in order to scratch out a living. After facing the prospect of prison time for her criminal offenses, Frey instead has her sentence commuted by the judge, who gives her one final chance to set things right. However, things go wrong from that point on, and after a series of misadventures, Frey finds herself transported to a magical world, with no clear way home. Everything about Frey&#039;s origin story plaintively makes it clear that the player is expected to find her a sympathetic, or even relatable, character. The problem though is that this message definitely wasn&#039;t conveyed to whoever was in charge of writing the dialogue.<br />
# <br />
# Through both the written dialogue and the voice acting performance, Frey has all the personal likeability of nails on a chalkboard. If you were hoping that, over time, the player might find themselves connecting more with Frey, you probably shouldn&#039;t get your hopes up. Similar to <i>Outriders</i>, <i>Forspoken</i> makes the critical mistake of assuming random out-of-context swearing and an abrasive attitude are the two sole factors in a protagonist&#039;s personality. And since the player will be hearing quite a bit from Frey over the course of the game, this is no minor issue to overlook.<br />
# <br />
# <iframe class="youtube-player" type="text/html" src="https://www.youtube.com/embed/l06UYJftnPc"  frameborder="0"> </iframe><br />
# <br />
# <h2>An open world devoid of life...</h2><br />
# The gameplay mechanics are fairly in line with what one would expect of any other open-world RPG. There are different zones, farmable resources, a variety of enemy types of varying difficulty for you to grind XP and resources from, and of course, story missions for you to progress through. But none of it feels particularly gripping. Even only a few hours in, it&#039;s easy to lose interest in what you&#039;re doing. This is helped, of course, by the fact that <i>Forspoken</i>&#039;s PC optimization is so bad that it comparatively makes <i>Hogwarts Legacy</i> look like a perfectly smooth experience. <br />
# <br />
# <h2>Technical difficulties ahead...</h2><br />
# For the purposes of this review, <i>Forspoken</i> was played on both a desktop and laptop, with both sharing high-end intel i7 processors. The desktop boasted a Nvidia 2070 GTX gpu, and the laptop featured a Nvidia 3070 RTX gpu. Despite the game advertising that it only required a minimum GPU requirement of a Nvidia 1060, with the Nvidia 3070 RTX being the recommended GPU for high-end performance, you can rest assured that even with the latter firmly in place, your PC will struggle to consistently maintain a stable minimum of 1080p 60fps. After running benchtests using a variety of option configurations, including enabling and disabling Vsync, it became clear that even if the player reduced all graphical settings to their minimum values, and ran a 3070 RTX, there was still no way of completely mitigating the frame drops, stutter, and other similar issues. The lack of file optimization here is likewise absurd. As if offering a retail asking price of $69.99 for this mess of a game wasn&#039;t absurd on its own, the fact that the game requires over 150 GBs of HDD space makes it even less desirable. <br />
# <br />
# <h2>Final Thoughts:</h2><br />
# <i>Forspoken</i> is not worth either your money, or your time. Even were it offered for free, perhaps as part of a free weekend promotion on Steam, or as one of the rotating weekly free game giveaways on the Epic Games Store, it would still be too high a price to pay, as the time investment costs far outweigh the doubtful pleasure of experiencing what little <i>Forspoken</i> has to offer.<br />
# <br />
# <br />
# <i>As always, follow us on <a href="https://www.instagram.com/hooked_gamers/" target="new">Instagram</a> for news updates, reviews, competitions and more.</i>
#
# 	</section>
#
# 	<section class="grade">
#
#
#
# 			<div class="grade">
# 				<p itemprop="rating"><meta itemprop="best" content="10"/>4.0</p>
# 				<p>fun score</p>
#             </div>
#
#
# 			<h3>Pros</h3>
# 				<p>It frequently is so bad, it's almost good.</p>
# 				<h3>Cons</h3>
#
# 				<p>Awful optimization, cringeworthy dialogue, forgettable narrative, and mediocre gameplay</p>
#                                 	</section>
#
#
# 		<section class="screens">
# 		<div class="gallery">
# 		<a href="/images/7017/forspoken/screenshot_pc_forspoken001.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken001_th.jpg"></a><a href="/images/7017/forspoken/screenshot_pc_forspoken002.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken002_th.jpg"></a><a href="/images/7017/forspoken/screenshot_pc_forspoken003.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken003_th.jpg"></a><a href="/images/7017/forspoken/screenshot_pc_forspoken004.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken004_th.jpg"></a><a href="/images/7017/forspoken/screenshot_pc_forspoken005.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken005_th.jpg"></a><a href="/images/7017/forspoken/screenshot_pc_forspoken006.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken006_th.jpg"></a><a href="/images/7017/forspoken/screenshot_pc_forspoken007.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken007_th.jpg"></a><a href="/images/7017/forspoken/screenshot_pc_forspoken008.jpg" title="Enlarge this screenshot"><img src="/images/7017/forspoken/screenshot_pc_forspoken008_th.jpg"></a>		</section>
# 		</div>
#
# 	</article>
#
#
#
#
# 		<div class="screenOverlay" id="screenOverlay" onclick="closeWindow();">
# 		</div>
# 		<div class="screenDisplay" id="screenDisplay">
# 			<a name="screenshot"></a>
# 			<table cellpadding="0" cellspacing="0" class="table_center">
# 				<tr>
# 					<td class="screens_main" valign="top" id="showScreen">&nbsp;
#
# 					</td>
# 				</tr>
# 			</table>
# 		</div>
#
#
# <aside>
# 		<div class="ad">
# 						<script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 			<!-- rectangle sidebar -->
# 			<ins class="adsbygoogle"
# 				 style="display:block"
# 				 data-ad-client="ca-pub-0020849830068151"
# 				 data-ad-slot="1659068609"
# 				 data-ad-format="auto"></ins>
# 			<script>
# 			(adsbygoogle = window.adsbygoogle || []).push({});
# 			</script>
#
# 		</div>
#
#     <!-- div class="ad">
#             <a title="Hooked Gamers Game of the Year 2017" href="/content/specials/game_of_the_year_2017/">
#                 <div class="block">
#                     <img alt="Game of the Year 2017 Logo" style="height: 286px; width: 300px;" src="/content/specials/game_of_the_year_2017/im/game_of_the_year_2017.png">
#                 </div>
#             </a>
#     </div -->
#
#
# <div class="news articles">
# <div class="block"><a href="/pc/hi-fi_rush/review/article-2407.html"><img src="/images/7027/hi-fi_rush/reviews/header_2407_hi-fi_rush.jpg" /><span>REVIEW</span><div><h2>Hi-Fi Rush</h2><p>Style and Substance</p></div></a></div><div class="block"><a href="/features/2023/03/04/plan_a_safe_and_fun_gambling_getaway_in_the_uk.html"><img src="/content/features/608/header.jpg" /><span>FEATURE</span><div><h2>Plan a Safe and Fun Gambling Getaway in the UK</h2><p></p></div></a></div><div class="block"><a href="/blogs/kingwilly/2023/03/02/extended_dead_island_2_trailer_revealed.html"><img src="/content/blogs/13148/header.jpg" /><span>NEWS</span><div><h2>Extended Dead island 2 trailer revealed</h2><p></p></div></a></div><div class="block"><a href="/blogs/kingwilly/2023/03/02/free_weekend_of_f1_manager_to_celebrate_the_start_of_f1_season.html"><img src="/content/blogs/13147/header.jpg" /><span>NEWS</span><div><h2>Free weekend of F1 Manager to celebrate the start of F1 season</h2><p></p></div></a></div><div class="block"><a href="/blogs/kingwilly/2023/03/01/run_a_magic_inn_with_friends_innchanted_launches_on_steam_march_28.html"><img src="/content/blogs/13146/header.jpg" /><span>NEWS</span><div><h2>Run a Magic Inn with Friends: Innchanted Launches on Steam March 28</h2><p>15% discount for pre-orders</p></div></a></div>	</div>
#
#
# </aside>
# </section>
# <footer>
# 	<nav class="columns conform">
# 		<div class="block">
# 			<h3>About</h3>
# 			<ul>
# 				<li><a href="/contact/">Contact</a></li>
# 				<li><a href="/contact/privacy.php">Privacy policy</a></li>
# 				<li><a href="/contact/terms.php">Terms &amp; conditions</a></li>
# 				<li><a href="/contact/howwerate.php">How we rate</a></li>
# 			</ul>
# 		</div>
#
# 		<div class="block">
# 			<h3>Connect</h3>
# 			<ul>
# 				<li><a href="/rss/all.php">RSS</a></li>
# 				<li><a href="/contact/updates.php">Mailing list</a></li>
# 			</ul>
# 		</div>
#
# 		<div class="block">
# 			<h3>Social</h3>
# 			<ul>
# 				<li><a target="blank" href="https://www.facebook.com/hookedgamers/">Facebook</a></li>
# 				<!--li><a target="blank" href="https://plus.google.com/100769119199311281811/posts">Google+</a></li-->
# 				<li><a target="blank" href="http://twitter.com/HookedGamers">Twitter</a></li>
# 				<li><a target="blank" href="http://steamcommunity.com/groups/hookedgamers#curation">Steam</a></li>
# 				<li><a target="blank" href="http://www.youtube.com/HookedGamers">Youtube</a></li>
# 			</ul>
# 		</div>
#
# 		<div class="block">
# 			<h3>Partners</h3>
# 			<ul>
# 				<li><a target="blank" href="http://www.metacritic.com/">MetaCritic</a></li>
# 				<li><a target="blank" href="http://www.gamerankings.com/">GameRankings</a></li>
# 				<li><a target="blank" href="http://www.cheathappens.com/">Cheat Happens</a></li>
# 				<li><a target="blank" href="http://gamingbolt.com/">GamingBolt</a></li>
# 			</ul>
# 		</div>
#
# 		<div class="block">
# 			<h3>Resources</h3>
# 			<ul>
# 				<li><a href="/highest_rated.html">Highest rated games</a></li>
# 				<li><a href="/games.html">All games</a></li>
# 			</ul>
# 		</div>
#
# 		<div class="copyright">
# 			<p>&copy; 2018 Cutlass Isle, all rights reserved</p>
# 		</div>
# 	</nav>
# </footer>
#
# <script src="/_inc/js/jquery.js"></script>
# <script src="/_inc/js/main.js"></script>
# <script src="/_inc/js/simple-lightbox.min.js"></script>
#
# <script type="text/javascript">
# 	jQuery(function($){
#     	     $( '.menu-btn' ).click(function(){
#     	     $('.responsive-menu').toggleClass('expand')
#     	     })
#         })
#
#         $('.search').on("click", function (e) {
# 	        e.preventDefault();
#             $('.searchFld').toggleClass("fullBar");
#             $('.searchBox>a').toggleClass("fullIcon");
#         });
#
# 	$(function(){
# 		var $gallery = $('.gallery a').simpleLightbox({closeText :'x'});
#
#
# 	});
# </script>
#
# </body>
# </html>

# %% [markdown]
# ### Parse

# %%
# All properties of object article
article.parse()
pprint(vars(article))
# Out:
# {'additional_data': {},
#  'article_html': '<div><h2>Aims low, lands lower.</h2><br>\r\n'
#                  "Under the mire of <i>Forspoken</i>'s many flaws, there is "
#                  'the individual fragments of what could have been a highly '
#                  'compelling, or at least passable, narrative. '
#                  '<i>Forspoken</i> follows the character of Frey, who grew up '
#                  'with no family, no prospects, and forced to rely on street '
#                  'gangs in order to scratch out a living. After facing the '
#                  'prospect of prison time for her criminal offenses, Frey '
#                  'instead has her sentence commuted by the judge, who gives '
#                  'her one final chance to set things right. However, things go '
#                  'wrong from that point on, and after a series of '
#                  'misadventures, Frey finds herself transported to a magical '
#                  "world, with no clear way home. Everything about Frey's "
#                  'origin story plaintively makes it clear that the player is '
#                  'expected to find her a sympathetic, or even relatable, '
#                  'character. The problem though is that this message '
#                  "definitely wasn't conveyed to whoever was in charge of "
#                  'writing the dialogue.<br>\r\n'
#                  '<br>\r\n'
#                  'Through both the written dialogue and the voice acting '
#                  'performance, Frey has all the personal likeability of nails '
#                  'on a chalkboard. If you were hoping that, over time, the '
#                  'player might find themselves connecting more with Frey, you '
#                  "probably shouldn't get your hopes up. Similar to "
#                  '<i>Outriders</i>, <i>Forspoken</i> makes the critical '
#                  'mistake of assuming random out-of-context swearing and an '
#                  'abrasive attitude are the two sole factors in a '
#                  "protagonist's personality. And since the player will be "
#                  'hearing quite a bit from Frey over the course of the game, '
#                  'this is no minor issue to overlook.<br>\r\n'
#                  '<br>\r\n'
#                  ' <br>\r\n'
#                  '<br>\r\n'
#                  '<h2>An open world devoid of life...</h2><br>\r\n'
#                  'The gameplay mechanics are fairly in line with what one '
#                  'would expect of any other open-world RPG. There are '
#                  'different zones, farmable resources, a variety of enemy '
#                  'types of varying difficulty for you to grind XP and '
#                  'resources from, and of course, story missions for you to '
#                  'progress through. But none of it feels particularly '
#                  "gripping. Even only a few hours in, it's easy to lose "
#                  "interest in what you're doing. This is helped, of course, by "
#                  "the fact that <i>Forspoken</i>'s PC optimization is so bad "
#                  'that it comparatively makes <i>Hogwarts Legacy</i> look like '
#                  'a perfectly smooth experience. <br>\r\n'
#                  '<br>\r\n'
#                  '<h2>Technical difficulties ahead...</h2><br>\r\n'
#                  'For the purposes of this review, <i>Forspoken</i> was played '
#                  'on both a desktop and laptop, with both sharing high-end '
#                  'intel i7 processors. The desktop boasted a Nvidia 2070 GTX '
#                  'gpu, and the laptop featured a Nvidia 3070 RTX gpu. Despite '
#                  'the game advertising that it only required a minimum GPU '
#                  'requirement of a Nvidia 1060, with the Nvidia 3070 RTX being '
#                  'the recommended GPU for high-end performance, you can rest '
#                  'assured that even with the latter firmly in place, your PC '
#                  'will struggle to consistently maintain a stable minimum of '
#                  '1080p 60fps. After running benchtests using a variety of '
#                  'option configurations, including enabling and disabling '
#                  'Vsync, it became clear that even if the player reduced all '
#                  'graphical settings to their minimum values, and ran a 3070 '
#                  'RTX, there was still no way of completely mitigating the '
#                  'frame drops, stutter, and other similar issues. The lack of '
#                  'file optimization here is likewise absurd. As if offering a '
#                  "retail asking price of $69.99 for this mess of a game wasn't "
#                  'absurd on its own, the fact that the game requires over 150 '
#                  'GBs of HDD space makes it even less desirable. <br>\r\n'
#                  '<br>\r\n'
#                  '<h2>Final Thoughts:</h2><br>\r\n'
#                  '<i>Forspoken</i> is not worth either your money, or your '
#                  'time. Even were it offered for free, perhaps as part of a '
#                  'free weekend promotion on Steam, or as one of the rotating '
#                  'weekly free game giveaways on the Epic Games Store, it would '
#                  'still be too high a price to pay, as the time investment '
#                  'costs far outweigh the doubtful pleasure of experiencing '
#                  'what little <i>Forspoken</i> has to offer.<br>\r\n'
#                  '<br>\r\n'
#                  '<br>\r\n'
#                  '<i>As always, follow us on <a '
#                  'href="https://www.instagram.com/hooked_gamers/" '
#                  'target="new">Instagram</a> for news updates, reviews, '
#                  'competitions and more.</i>\n'
#                  '\t\t\t\t\n'
#                  "\t<p>Under the mire of's many flaws, there is the individual "
#                  'fragments of what could have been a highly compelling, or at '
#                  'least passable, narrative.follows the character of Frey, who '
#                  'grew up with no family, no prospects, and forced to rely on '
#                  'street gangs in order to scratch out a living. After facing '
#                  'the prospect of prison time for her criminal offenses, Frey '
#                  'instead has her sentence commuted by the judge, who gives '
#                  'her one final chance to set things right. However, things go '
#                  'wrong from that point on, and after a series of '
#                  'misadventures, Frey finds herself transported to a magical '
#                  "world, with no clear way home. Everything about Frey's "
#                  'origin story plaintively makes it clear that the player is '
#                  'expected to find her a sympathetic, or even relatable, '
#                  'character. The problem though is that this message '
#                  "definitely wasn't conveyed to whoever was in charge of "
#                  'writing the dialogue.Through both the written dialogue and '
#                  'the voice acting performance, Frey has all the personal '
#                  'likeability of nails on a chalkboard. If you were hoping '
#                  'that, over time, the player might find themselves connecting '
#                  "more with Frey, you probably shouldn't get your hopes up. "
#                  'Similar tomakes the critical mistake of assuming random '
#                  'out-of-context swearing and an abrasive attitude are the two '
#                  "sole factors in a protagonist's personality. And since the "
#                  'player will be hearing quite a bit from Frey over the course '
#                  'of the game, this is no minor issue to overlook.The gameplay '
#                  'mechanics are fairly in line with what one would expect of '
#                  'any other open-world RPG. There are different zones, '
#                  'farmable resources, a variety of enemy types of varying '
#                  'difficulty for you to grind XP and resources from, and of '
#                  'course, story missions for you to progress through. But none '
#                  'of it feels particularly gripping. Even only a few hours in, '
#                  "it's easy to lose interest in what you're doing. This is "
#                  "helped, of course, by the fact that's PC optimization is so "
#                  'bad that it comparatively makeslook like a perfectly smooth '
#                  'experience.For the purposes of this review,was played on '
#                  'both a desktop and laptop, with both sharing high-end intel '
#                  'i7 processors. The desktop boasted a Nvidia 2070 GTX gpu, '
#                  'and the laptop featured a Nvidia 3070 RTX gpu. Despite the '
#                  'game advertising that it only required a minimum GPU '
#                  'requirement of a Nvidia 1060, with the Nvidia 3070 RTX being '
#                  'the recommended GPU for high-end performance, you can rest '
#                  'assured that even with the latter firmly in place, your PC '
#                  'will struggle to consistently maintain a stable minimum of '
#                  '1080p 60fps. After running benchtests using a variety of '
#                  'option configurations, including enabling and disabling '
#                  'Vsync, it became clear that even if the player reduced all '
#                  'graphical settings to their minimum values, and ran a 3070 '
#                  'RTX, there was still no way of completely mitigating the '
#                  'frame drops, stutter, and other similar issues. The lack of '
#                  'file optimization here is likewise absurd. As if offering a '
#                  "retail asking price of $69.99 for this mess of a game wasn't "
#                  'absurd on its own, the fact that the game requires over 150 '
#                  'GBs of HDD space makes it even less desirable.is not worth '
#                  'either your money, or your time. Even were it offered for '
#                  'free, perhaps as part of a free weekend promotion on Steam, '
#                  'or as one of the rotating weekly free game giveaways on the '
#                  'Epic Games Store, it would still be too high a price to pay, '
#                  'as the time investment costs far outweigh the doubtful '
#                  'pleasure of experiencing what littlehas to '
#                  'offer.</p></div>\n',
#  'authors': [],
#  'canonical_link': '',
#  'clean_doc': <Element html at 0x21949e10ef0>,
#  'clean_top_node': <Element section at 0x21907317bd0>,
#  'config': <newspaper.configuration.Configuration object at 0x0000021949E04820>,
#  'doc': <Element html at 0x21949e10d60>,
#  'download_exception_msg': None,
#  'download_state': 2,
#  'extractor': <newspaper.extractors.ContentExtractor object at 0x0000021949E047C0>,
#  'html': '<!DOCTYPE html>\n'
#          '<html lang="en" xmlns="https://www.w3.org/1999/xhtml">\n'
#          '<head>\n'
#          ' \t<meta http-equiv="Content-Type" content="text/html; '
#          'charset=utf-8">\n'
#          '\t<meta property="fb:app_id" content="337785116266465"/>\n'
#          '    <meta name="viewport" content="width=device-width" />\n'
#          '    <meta name="application-name" content="Hooked Gamers" />\n'
#          '    <meta name="description" content="We played Forspoken - It '
#          "frequently is so bad, it's almost good. Awful optimization, "
#          'cringeworthy dialogue, forgettable narrative, and mediocre '
#          'gameplay">\n'
#          '    <meta name="keywords" content="Forspoken, Action-Adventure game, '
#          'Square Enix, Luminous Productions" />\n'
#          '\t<title>Forspoken PC review - "Forspoken should be forgotten" | '
#          'Hooked Gamers</title>\n'
#          '\t<meta property="og:image" '
#          'content="https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg" '
#          '/>\n'
#          '\t<meta property="og:image:type" content="image/jpeg" /> \t\n'
#          '\n'
#          '\t<meta property="fb:app_id"       content="337785116266465" />\t\n'
#          '\t<link '
#          "href='//fonts.googleapis.com/css?family=Open+Sans:400,800,700,400italic,700italic,800italic' "
#          "rel='stylesheet' type='text/css'>\n"
#          '    <link rel="stylesheet" href="/_inc/style.css" />\n'
#          '\n'
#          '<script type="text/javascript">\n'
#          '\n'
#          '  var _gaq = _gaq || [];\n'
#          "  _gaq.push(['_setAccount', 'UA-563957-1']);\n"
#          "  _gaq.push(['_trackPageview']);\n"
#          '\n'
#          '  (function() {\n'
#          "    var ga = document.createElement('script'); ga.type = "
#          "'text/javascript'; ga.async = true;\n"
#          "    ga.src = ('https:' == document.location.protocol ? 'https://' : "
#          "'http://') + 'stats.g.doubleclick.net/dc.js';\n"
#          "    var s = document.getElementsByTagName('script')[0]; "
#          's.parentNode.insertBefore(ga, s);\n'
#          '  })();\n'
#          '\n'
#          '</script>\n'
#          '\n'
#          "<script type='text/javascript'>\n"
#          'var googletag = googletag || {};\n'
#          'googletag.cmd = googletag.cmd || [];\n'
#          '(function() {\n'
#          "var gads = document.createElement('script');\n"
#          'gads.async = true;\n'
#          "gads.type = 'text/javascript';\n"
#          "var useSSL = 'https:' == document.location.protocol;\n"
#          "gads.src = (useSSL ? 'https:' : 'http:') +\n"
#          "'//www.googletagservices.com/tag/js/gpt.js';\n"
#          "var node = document.getElementsByTagName('script')[0];\n"
#          'node.parentNode.insertBefore(gads, node);\n'
#          '})();\n'
#          '</script>\n'
#          '\n'
#          '</head>\n'
#          '<body>\n'
#          '<div id="fb-root"></div>\n'
#          '<script>(function(d, s, id) {\n'
#          '  var js, fjs = d.getElementsByTagName(s)[0];\n'
#          '  if (d.getElementById(id)) return;\n'
#          '  js = d.createElement(s); js.id = id;\n'
#          '  js.src = '
#          '"//connect.facebook.net/en_US/sdk.js#xfbml=1&appId=337785116266465&version=v2.0";\n'
#          '  fjs.parentNode.insertBefore(js, fjs);\n'
#          "}(document, 'script', 'facebook-jssdk'));</script>\n"
#          '\n'
#          '<nav id="main-navigation">\n'
#          '<section class="nav">\n'
#          '\t<div class="top">\n'
#          '\t\t<div class="logo">\n'
#          '\t\t\t<a href="/"><img src="/_inc/im/hookedgamers.png"></a>\n'
#          '\t\t</div>\n'
#          '\t\t<div class="side">\n'
#          '\t\t\t<img src="/_inc/im/nav_background_small.png">\n'
#          '\n'
#          '\t\t\t<nav class="navTop">\n'
#          '\t\t\t\t<ul>\n'
#          '\t\t\t\t\t<li class="firstNav"><a href="/previews.html"><h3>EARLY '
#          'ACCESS SCOUT</h3>\n'
#          '\t\t\t\t\tLatest Steam Previews</a></li>\n'
#          '\t\t\t\t\t<!-- li class="firstNav"><a '
#          'href="/content/specials/game_of_the_year_2017/"><h3>GAME OF THE YEAR '
#          '2017</h3>\n'
#          '\t\t\t\t\tThe votes are in!</a></li -->\t\t\t\t\t\n'
#          '\t\t\t\t</ul>\n'
#          '\t\t\t</nav>\n'
#          '\n'
#          '\t\t\t<nav class="navBottom" style="z-index: 10;">\n'
#          '\t\t\t\t<div>\n'
#          '\t\t\t\t\t<form method="post" action="/search/">\n'
#          '\t\t\t\t\t\t<input type="hidden" class="searchVal" value="true" '
#          'name="search">\n'
#          '\t\t\t\t\t\t<input type="search" class="searchFld" placeholder="find '
#          'a game" name="gametitle">\n'
#          '\t\t\t\t\t\t<input type="submit" class="searchBtn" value="">\n'
#          '\t\t\t\t\t</form>\n'
#          '\t\t\t\t</div>\n'
#          '\t\t\t\t<ul>\n'
#          '\t\t\t\t\t<li><a title="hooked gamers home" href="/" >Home</a></li>\n'
#          '\t\t\t\t\t<li><a title="latest reviews" href="/reviews.html"  '
#          'class="active">Reviews</a></li>\n'
#          '\t\t\t\t\t<li><a title="latest previews" href="/previews.html" '
#          '>Previews</a></li>\n'
#          '\t\t\t\t\t<li><a title="specials and features" href="/features.html" '
#          '>Features</a></li>\n'
#          '\t\t\t\t\t<li><a title="new cheats" href="/cheats.html" '
#          '>Cheats</a></li>\n'
#          '\t\t\t\t\t<li><a title="upcoming games" href="/upcoming_games.html" '
#          '>Releases</a></li>\n'
#          '\t\t\t\t\t<li><a title="new screenshots" href="/screenshots.html" '
#          '>screens</a></li>\n'
#          '\t\t\t\t\t<li class="icon searchBox"><a href="#" class="search" '
#          'title="search"><i class="fa fa-search"></i></a></li>\n'
#          '\t\t\t\t\t<li class="icon"><a target="blank" '
#          'href="https://steamcommunity.com/groups/hookedgamers#curation" '
#          'title="visit our Steam page"><i class="fa fa-steam"></i></a></li>\n'
#          '\t\t\t\t\t<li class="icon"><a target="blank" title="like us on '
#          'Facebook" href="https://www.facebook.com/hookedgamers"><i class="fa '
#          'fa-facebook"></i></a></li>\n'
#          '\t\t\t\t\t<li class="icon"><a target="blank" title="follow us on '
#          'Twitter" href="https://twitter.com/HookedGamers"><i class="fa '
#          'fa-twitter"></i></a></li>\n'
#          '\t\t\t\t</ul>\n'
#          '\t\t\t</nav>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t\t<div class="mobile-nav">\n'
#          '\t\t\t <div class="menu-btn" id="menu-btn">\n'
#          '\t\t\t\t<i class="fa fa-bars"></i>\n'
#          '\t\t\t </div>\n'
#          '\n'
#          '\t\t\t <div class="responsive-menu">\n'
#          '\t\t\t\t<ul>\n'
#          '\t\t\t\t\t<li><a title="latest reviews" href="/reviews.html"  '
#          'class="active">Reviews</a></li>\n'
#          '\t\t\t\t\t<li><a title="latest previews" href="/previews.html" '
#          '>Previews</a></li>\n'
#          '\t\t\t\t\t<li><a title="specials and features" href="/features.html" '
#          '>Features</a></li>\n'
#          '\t\t\t\t\t<li><a title="new cheats" href="/cheats.html" '
#          '>Cheats</a></li>\n'
#          '\t\t\t\t\t<li><a title="upcoming games" href="/upcoming_games.html" '
#          '>Releases</a></li>\n'
#          '\t\t\t\t\t<li><a title="new screenshots" href="/screenshots.html" '
#          '>Screens</a></li>\n'
#          '\t\t\t\t\t<li><a target="blank" title="follow us on Twitter" '
#          'href="https://twitter.com/HookedGamers">Twitter</a></li>\n'
#          '\t\t\t\t\t<li><a target="blank" title="like us on Facebook" '
#          'href="https://www.facebook.com/hookedgamers">Facebook</a></li>\n'
#          '\t\t\t\t\t<li><a target="blank" '
#          'href="https://steamcommunity.com/groups/hookedgamers#curation" '
#          'title="visit our Steam page">Steam</a></li>\n'
#          '\t\t\t\t\t<li><a title="search" href="/search/">Search</a></li>\n'
#          '\t\t\t\t</ul>\n'
#          '\t\t\t </div>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t</div>\n'
#          '</section>\n'
#          '</nav>\n'
#          '\n'
#          '<section class="wrapper">\n'
#          '\n'
#          '\t<div class="topAd">\n'
#          '\t\t\t\t\t<script async '
#          'src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\n'
#          '\t\t\t<!-- full-width top -->\n'
#          '\t\t\t<ins class="adsbygoogle"\n'
#          '\t\t\t\t style="display:block"\n'
#          '\t\t\t\t data-ad-client="ca-pub-0020849830068151"\n'
#          '\t\t\t\t data-ad-slot="7705602205"\n'
#          '\t\t\t\t data-ad-format="auto"></ins>\n'
#          '\t\t\t<script>\n'
#          '\t\t\t(adsbygoogle = window.adsbygoogle || []).push({});\n'
#          '\t\t\t</script>\n'
#          '\t</div>\n'
#          '\t<article class="content">\n'
#          '\t\t<header class="block">\n'
#          '\t\t\t<div class="gameTitle">\n'
#          '\t\t\t\t<h1>Forspoken</h1>\n'
#          '\t\t\t\t<div><p><a href="/pc/forspoken.html" title="Overview of '
#          'Forspoken"><font>More</font><span> info</span> &raquo</a></p></div>\n'
#          '\t\t\t</div>\n'
#          '\t\t\t<img '
#          'src="/images/7017/forspoken/reviews/header_2402_forspoken.jpg" '
#          'alt="Forspoken review" class="header" />\n'
#          '\t\t\t<div>\n'
#          '\t\t\t\t<a href="/blogs/danlenois/overview.html">\n'
#          '\n'
#          '\t\t\t\t\t\n'
#          '\t\t\t\t\t\t<img src="/_nhg/base/im/contact/avatar_danlenois.jpg" '
#          'alt="Dan Lenois" title="Dan Lenois">\n'
#          '\t\t\t\t\t\t\t\t\t\t\t\n'
#          '\t\t\t\t\t\n'
#          '\t\t\t\t</a>\n'
#          '\t\t\t\t<h3>Review</h3>\t\n'
#          '\t\t\t\t<h2>Forspoken should be forgotten</h2>\n'
#          '\t\t\t</div>\n'
#          '\t\t</header>\n'
#          '\n'
#          '\t\t<div class="articleInfo">\n'
#          '\t\t\t<time><span itemprop="dtreviewed" '
#          'datetime="2023-02-15">February 15th, 2023</span></time> by <a '
#          'itemprop="reviewer" href="/blogs/danlenois/overview.html">Dan '
#          'Lenois</a>\n'
#          '\t\t\t<div><font>reviewed on </font><span>PC</span></div>\n'
#          '\t\t</div>\n'
#          '\n'
#          '               \n'
#          '\t<section class="article" itemscope '
#          'itemtype="http://data-vocabulary.org/Review">\t\t\t\n'
#          '                \n'
#          '\n'
#          '\t\t\t\t<h2>Aims low, lands lower.</h2><br />\r\n'
#          'Under the mire of <i>Forspoken</i>&#039;s many flaws, there is the '
#          'individual fragments of what could have been a highly compelling, or '
#          'at least passable, narrative. <i>Forspoken</i> follows the character '
#          'of Frey, who grew up with no family, no prospects, and forced to '
#          'rely on street gangs in order to scratch out a living. After facing '
#          'the prospect of prison time for her criminal offenses, Frey instead '
#          'has her sentence commuted by the judge, who gives her one final '
#          'chance to set things right. However, things go wrong from that point '
#          'on, and after a series of misadventures, Frey finds herself '
#          'transported to a magical world, with no clear way home. Everything '
#          'about Frey&#039;s origin story plaintively makes it clear that the '
#          'player is expected to find her a sympathetic, or even relatable, '
#          'character. The problem though is that this message definitely '
#          'wasn&#039;t conveyed to whoever was in charge of writing the '
#          'dialogue.<br />\r\n'
#          '<br />\r\n'
#          'Through both the written dialogue and the voice acting performance, '
#          'Frey has all the personal likeability of nails on a chalkboard. If '
#          'you were hoping that, over time, the player might find themselves '
#          'connecting more with Frey, you probably shouldn&#039;t get your '
#          'hopes up. Similar to <i>Outriders</i>, <i>Forspoken</i> makes the '
#          'critical mistake of assuming random out-of-context swearing and an '
#          'abrasive attitude are the two sole factors in a protagonist&#039;s '
#          'personality. And since the player will be hearing quite a bit from '
#          'Frey over the course of the game, this is no minor issue to '
#          'overlook.<br />\r\n'
#          '<br />\r\n'
#          '<iframe class="youtube-player" type="text/html" '
#          'src="https://www.youtube.com/embed/l06UYJftnPc"  frameborder="0"> '
#          '</iframe><br />\r\n'
#          '<br />\r\n'
#          '<h2>An open world devoid of life...</h2><br />\r\n'
#          'The gameplay mechanics are fairly in line with what one would expect '
#          'of any other open-world RPG. There are different zones, farmable '
#          'resources, a variety of enemy types of varying difficulty for you to '
#          'grind XP and resources from, and of course, story missions for you '
#          'to progress through. But none of it feels particularly gripping. '
#          'Even only a few hours in, it&#039;s easy to lose interest in what '
#          'you&#039;re doing. This is helped, of course, by the fact that '
#          '<i>Forspoken</i>&#039;s PC optimization is so bad that it '
#          'comparatively makes <i>Hogwarts Legacy</i> look like a perfectly '
#          'smooth experience. <br />\r\n'
#          '<br />\r\n'
#          '<h2>Technical difficulties ahead...</h2><br />\r\n'
#          'For the purposes of this review, <i>Forspoken</i> was played on both '
#          'a desktop and laptop, with both sharing high-end intel i7 '
#          'processors. The desktop boasted a Nvidia 2070 GTX gpu, and the '
#          'laptop featured a Nvidia 3070 RTX gpu. Despite the game advertising '
#          'that it only required a minimum GPU requirement of a Nvidia 1060, '
#          'with the Nvidia 3070 RTX being the recommended GPU for high-end '
#          'performance, you can rest assured that even with the latter firmly '
#          'in place, your PC will struggle to consistently maintain a stable '
#          'minimum of 1080p 60fps. After running benchtests using a variety of '
#          'option configurations, including enabling and disabling Vsync, it '
#          'became clear that even if the player reduced all graphical settings '
#          'to their minimum values, and ran a 3070 RTX, there was still no way '
#          'of completely mitigating the frame drops, stutter, and other similar '
#          'issues. The lack of file optimization here is likewise absurd. As if '
#          'offering a retail asking price of $69.99 for this mess of a game '
#          'wasn&#039;t absurd on its own, the fact that the game requires over '
#          '150 GBs of HDD space makes it even less desirable. <br />\r\n'
#          '<br />\r\n'
#          '<h2>Final Thoughts:</h2><br />\r\n'
#          '<i>Forspoken</i> is not worth either your money, or your time. Even '
#          'were it offered for free, perhaps as part of a free weekend '
#          'promotion on Steam, or as one of the rotating weekly free game '
#          'giveaways on the Epic Games Store, it would still be too high a '
#          'price to pay, as the time investment costs far outweigh the doubtful '
#          'pleasure of experiencing what little <i>Forspoken</i> has to '
#          'offer.<br />\r\n'
#          '<br />\r\n'
#          '<br />\r\n'
#          '<i>As always, follow us on <a '
#          'href="https://www.instagram.com/hooked_gamers/" '
#          'target="new">Instagram</a> for news updates, reviews, competitions '
#          'and more.</i>\n'
#          '\t\t\t\t\n'
#          '\t</section>\n'
#          '\n'
#          '\t<section class="grade">\n'
#          '\n'
#          '\n'
#          '\t\t\t\n'
#          '\t\t\t<div class="grade">\n'
#          '\t\t\t\t<p itemprop="rating"><meta itemprop="best" '
#          'content="10"/>4.0</p>\n'
#          '\t\t\t\t<p>fun score</p>\n'
#          '            </div>\n'
#          '\n'
#          '\t\t\t\n'
#          '\t\t\t<h3>Pros</h3>\n'
#          "\t\t\t\t<p>It frequently is so bad, it's almost good.</p>\n"
#          '\t\t\t\t<h3>Cons</h3>\n'
#          '\n'
#          '\t\t\t\t<p>Awful optimization, cringeworthy dialogue, forgettable '
#          'narrative, and mediocre gameplay</p>\n'
#          '                                \t</section>\n'
#          '\n'
#          '\n'
#          '\t\t<section class="screens">\n'
#          '\t\t<div class="gallery">\n'
#          '\t\t<a href="/images/7017/forspoken/screenshot_pc_forspoken001.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken001_th.jpg"></a><a '
#          'href="/images/7017/forspoken/screenshot_pc_forspoken002.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken002_th.jpg"></a><a '
#          'href="/images/7017/forspoken/screenshot_pc_forspoken003.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken003_th.jpg"></a><a '
#          'href="/images/7017/forspoken/screenshot_pc_forspoken004.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken004_th.jpg"></a><a '
#          'href="/images/7017/forspoken/screenshot_pc_forspoken005.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken005_th.jpg"></a><a '
#          'href="/images/7017/forspoken/screenshot_pc_forspoken006.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken006_th.jpg"></a><a '
#          'href="/images/7017/forspoken/screenshot_pc_forspoken007.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken007_th.jpg"></a><a '
#          'href="/images/7017/forspoken/screenshot_pc_forspoken008.jpg" '
#          'title="Enlarge this screenshot"><img '
#          'src="/images/7017/forspoken/screenshot_pc_forspoken008_th.jpg"></a>\t\t'
#          '</section>\n'
#          '\t\t</div>\n'
#          '\t\t\n'
#          '\t</article>\n'
#          '\n'
#          '\n'
#          '\n'
#          '\n'
#          '\t\t<div class="screenOverlay" id="screenOverlay" '
#          'onclick="closeWindow();">\n'
#          '\t\t</div>\n'
#          '\t\t<div class="screenDisplay" id="screenDisplay">\n'
#          '\t\t\t<a name="screenshot"></a>\n'
#          '\t\t\t<table cellpadding="0" cellspacing="0" class="table_center">\n'
#          '\t\t\t\t<tr>\n'
#          '\t\t\t\t\t<td class="screens_main" valign="top" '
#          'id="showScreen">&nbsp;\n'
#          '\t\t\t\t\t\t\n'
#          '\t\t\t\t\t</td>\n'
#          '\t\t\t\t</tr>\n'
#          '\t\t\t</table>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t\t\n'
#          '<aside>\n'
#          '\t\t<div class="ad">\n'
#          '\t\t\t\t\t\t<script async '
#          'src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>\n'
#          '\t\t\t<!-- rectangle sidebar -->\n'
#          '\t\t\t<ins class="adsbygoogle"\n'
#          '\t\t\t\t style="display:block"\n'
#          '\t\t\t\t data-ad-client="ca-pub-0020849830068151"\n'
#          '\t\t\t\t data-ad-slot="1659068609"\n'
#          '\t\t\t\t data-ad-format="auto"></ins>\n'
#          '\t\t\t<script>\n'
#          '\t\t\t(adsbygoogle = window.adsbygoogle || []).push({});\n'
#          '\t\t\t</script>\n'
#          '\n'
#          '\t\t</div>\n'
#          '\n'
#          '    <!-- div class="ad">\n'
#          '            <a title="Hooked Gamers Game of the Year 2017" '
#          'href="/content/specials/game_of_the_year_2017/">\n'
#          '                <div class="block">\n'
#          '                    <img alt="Game of the Year 2017 Logo" '
#          'style="height: 286px; width: 300px;" '
#          'src="/content/specials/game_of_the_year_2017/im/game_of_the_year_2017.png">\n'
#          '                </div>\n'
#          '            </a>\n'
#          '    </div -->  \n'
#          '\n'
#          '\n'
#          '<div class="news articles">\n'
#          '<div class="block"><a '
#          'href="/pc/hi-fi_rush/review/article-2407.html"><img '
#          'src="/images/7027/hi-fi_rush/reviews/header_2407_hi-fi_rush.jpg" '
#          '/><span>REVIEW</span><div><h2>Hi-Fi Rush</h2><p>Style and '
#          'Substance</p></div></a></div><div class="block"><a '
#          'href="/features/2023/03/04/plan_a_safe_and_fun_gambling_getaway_in_the_uk.html"><img '
#          'src="/content/features/608/header.jpg" '
#          '/><span>FEATURE</span><div><h2>Plan a Safe and Fun Gambling Getaway '
#          'in the UK</h2><p></p></div></a></div><div class="block"><a '
#          'href="/blogs/kingwilly/2023/03/02/extended_dead_island_2_trailer_revealed.html"><img '
#          'src="/content/blogs/13148/header.jpg" '
#          '/><span>NEWS</span><div><h2>Extended Dead island 2 trailer '
#          'revealed</h2><p></p></div></a></div><div class="block"><a '
#          'href="/blogs/kingwilly/2023/03/02/free_weekend_of_f1_manager_to_celebrate_the_start_of_f1_season.html"><img '
#          'src="/content/blogs/13147/header.jpg" '
#          '/><span>NEWS</span><div><h2>Free weekend of F1 Manager to celebrate '
#          'the start of F1 season</h2><p></p></div></a></div><div '
#          'class="block"><a '
#          'href="/blogs/kingwilly/2023/03/01/run_a_magic_inn_with_friends_innchanted_launches_on_steam_march_28.html"><img '
#          'src="/content/blogs/13146/header.jpg" '
#          '/><span>NEWS</span><div><h2>Run a Magic Inn with Friends: Innchanted '
#          'Launches on Steam March 28</h2><p>15% discount for '
#          'pre-orders</p></div></a></div>\t</div>\n'
#          '\n'
#          '\n'
#          '</aside>\n'
#          '</section>\n'
#          '<footer>\n'
#          '\t<nav class="columns conform">\n'
#          '\t\t<div class="block">\n'
#          '\t\t\t<h3>About</h3>\n'
#          '\t\t\t<ul>\n'
#          '\t\t\t\t<li><a href="/contact/">Contact</a></li>\n'
#          '\t\t\t\t<li><a href="/contact/privacy.php">Privacy policy</a></li>\n'
#          '\t\t\t\t<li><a href="/contact/terms.php">Terms &amp; '
#          'conditions</a></li>\n'
#          '\t\t\t\t<li><a href="/contact/howwerate.php">How we rate</a></li>\n'
#          '\t\t\t</ul>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t\t<div class="block">\n'
#          '\t\t\t<h3>Connect</h3>\n'
#          '\t\t\t<ul>\n'
#          '\t\t\t\t<li><a href="/rss/all.php">RSS</a></li>\n'
#          '\t\t\t\t<li><a href="/contact/updates.php">Mailing list</a></li>\n'
#          '\t\t\t</ul>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t\t<div class="block">\n'
#          '\t\t\t<h3>Social</h3>\n'
#          '\t\t\t<ul>\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="https://www.facebook.com/hookedgamers/">Facebook</a></li>\n'
#          '\t\t\t\t<!--li><a target="blank" '
#          'href="https://plus.google.com/100769119199311281811/posts">Google+</a></li-->\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="http://twitter.com/HookedGamers">Twitter</a></li>\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="http://steamcommunity.com/groups/hookedgamers#curation">Steam</a></li>\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="http://www.youtube.com/HookedGamers">Youtube</a></li>\n'
#          '\t\t\t</ul>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t\t<div class="block">\n'
#          '\t\t\t<h3>Partners</h3>\n'
#          '\t\t\t<ul>\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="http://www.metacritic.com/">MetaCritic</a></li>\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="http://www.gamerankings.com/">GameRankings</a></li>\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="http://www.cheathappens.com/">Cheat Happens</a></li>\n'
#          '\t\t\t\t<li><a target="blank" '
#          'href="http://gamingbolt.com/">GamingBolt</a></li>\n'
#          '\t\t\t</ul>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t\t<div class="block">\n'
#          '\t\t\t<h3>Resources</h3>\n'
#          '\t\t\t<ul>\n'
#          '\t\t\t\t<li><a href="/highest_rated.html">Highest rated '
#          'games</a></li>\n'
#          '\t\t\t\t<li><a href="/games.html">All games</a></li>\n'
#          '\t\t\t</ul>\n'
#          '\t\t</div>\n'
#          '\n'
#          '\t\t<div class="copyright">\n'
#          '\t\t\t<p>&copy; 2018 Cutlass Isle, all rights reserved</p>\n'
#          '\t\t</div>\n'
#          '\t</nav>\n'
#          '</footer>\n'
#          '\n'
#          '<script src="/_inc/js/jquery.js"></script>\n'
#          '<script src="/_inc/js/main.js"></script>\n'
#          '<script src="/_inc/js/simple-lightbox.min.js"></script>\n'
#          '\n'
#          '<script type="text/javascript">\n'
#          '\tjQuery(function($){\n'
#          "    \t     $( '.menu-btn' ).click(function(){\n"
#          "    \t     $('.responsive-menu').toggleClass('expand')\n"
#          '    \t     })\n'
#          '        })\n'
#          '\n'
#          '        $(\'.search\').on("click", function (e) {\n'
#          '\t        e.preventDefault();\n'
#          '            $(\'.searchFld\').toggleClass("fullBar");\n'
#          '            $(\'.searchBox>a\').toggleClass("fullIcon");\n'
#          '        });\n'
#          '\n'
#          '\t$(function(){\n'
#          "\t\tvar $gallery = $('.gallery a').simpleLightbox({closeText "
#          ":'x'});\n"
#          '\n'
#          '\n'
#          '\t});\n'
#          '</script>\n'
#          '\n'
#          '</body>\n'
#          '</html>',
#  'images': {'https://www.hookedgamers.com/_inc/im/hookedgamers.png',
#             'https://www.hookedgamers.com/_inc/im/nav_background_small.png',
#             'https://www.hookedgamers.com/_nhg/base/im/contact/avatar_danlenois.jpg',
#             'https://www.hookedgamers.com/content/blogs/13146/header.jpg',
#             'https://www.hookedgamers.com/content/blogs/13147/header.jpg',
#             'https://www.hookedgamers.com/content/blogs/13148/header.jpg',
#             'https://www.hookedgamers.com/content/features/608/header.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken001_th.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken002_th.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken003_th.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken004_th.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken005_th.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken006_th.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken007_th.jpg',
#             'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken008_th.jpg',
#             'https://www.hookedgamers.com/images/7027/hi-fi_rush/reviews/header_2407_hi-fi_rush.jpg'},
#  'imgs': {'https://www.hookedgamers.com/_inc/im/hookedgamers.png',
#           'https://www.hookedgamers.com/_inc/im/nav_background_small.png',
#           'https://www.hookedgamers.com/_nhg/base/im/contact/avatar_danlenois.jpg',
#           'https://www.hookedgamers.com/content/blogs/13146/header.jpg',
#           'https://www.hookedgamers.com/content/blogs/13147/header.jpg',
#           'https://www.hookedgamers.com/content/blogs/13148/header.jpg',
#           'https://www.hookedgamers.com/content/features/608/header.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken001_th.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken002_th.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken003_th.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken004_th.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken005_th.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken006_th.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken007_th.jpg',
#           'https://www.hookedgamers.com/images/7017/forspoken/screenshot_pc_forspoken008_th.jpg',
#           'https://www.hookedgamers.com/images/7027/hi-fi_rush/reviews/header_2407_hi-fi_rush.jpg'},
#  'is_parsed': True,
#  'keywords': [],
#  'link_hash': '5c39ed26c324e995156fbef399224d01.1678043446.1141286',
#  'meta_data': defaultdict(<class 'dict'>,
#                           {'application-name': 'Hooked Gamers',
#                            'description': 'We played Forspoken - It frequently '
#                                           "is so bad, it's almost good. Awful "
#                                           'optimization, cringeworthy '
#                                           'dialogue, forgettable narrative, '
#                                           'and mediocre gameplay',
#                            'fb': {'app_id': 337785116266465},
#                            'keywords': 'Forspoken, Action-Adventure game, '
#                                        'Square Enix, Luminous Productions',
#                            'og': {'image': {'identifier': 'https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg',
#                                             'type': 'image/jpeg'}},
#                            'viewport': 'width=device-width'}),
#  'meta_description': "We played Forspoken - It frequently is so bad, it's "
#                      'almost good. Awful optimization, cringeworthy dialogue, '
#                      'forgettable narrative, and mediocre gameplay',
#  'meta_favicon': '',
#  'meta_img': 'https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg',
#  'meta_keywords': ['Forspoken',
#                    'Action-Adventure game',
#                    'Square Enix',
#                    'Luminous Productions'],
#  'meta_lang': 'en',
#  'movies': ['https://www.youtube.com/embed/l06UYJftnPc'],
#  'publish_date': None,
#  'source_url': 'https://www.hookedgamers.com',
#  'summary': '',
#  'tags': set(),
#  'text': 'Aims low, lands lower.\n'
#          '\n'
#          'An open world devoid of life...\n'
#          '\n'
#          'Technical difficulties ahead...\n'
#          '\n'
#          'Final Thoughts:\n'
#          '\n'
#          "Under the mire of's many flaws, there is the individual fragments of "
#          'what could have been a highly compelling, or at least passable, '
#          'narrative.follows the character of Frey, who grew up with no family, '
#          'no prospects, and forced to rely on street gangs in order to scratch '
#          'out a living. After facing the prospect of prison time for her '
#          'criminal offenses, Frey instead has her sentence commuted by the '
#          'judge, who gives her one final chance to set things right. However, '
#          'things go wrong from that point on, and after a series of '
#          'misadventures, Frey finds herself transported to a magical world, '
#          "with no clear way home. Everything about Frey's origin story "
#          'plaintively makes it clear that the player is expected to find her a '
#          'sympathetic, or even relatable, character. The problem though is '
#          "that this message definitely wasn't conveyed to whoever was in "
#          'charge of writing the dialogue.Through both the written dialogue and '
#          'the voice acting performance, Frey has all the personal likeability '
#          'of nails on a chalkboard. If you were hoping that, over time, the '
#          'player might find themselves connecting more with Frey, you probably '
#          "shouldn't get your hopes up. Similar tomakes the critical mistake of "
#          'assuming random out-of-context swearing and an abrasive attitude are '
#          "the two sole factors in a protagonist's personality. And since the "
#          'player will be hearing quite a bit from Frey over the course of the '
#          'game, this is no minor issue to overlook.The gameplay mechanics are '
#          'fairly in line with what one would expect of any other open-world '
#          'RPG. There are different zones, farmable resources, a variety of '
#          'enemy types of varying difficulty for you to grind XP and resources '
#          'from, and of course, story missions for you to progress through. But '
#          'none of it feels particularly gripping. Even only a few hours in, '
#          "it's easy to lose interest in what you're doing. This is helped, of "
#          "course, by the fact that's PC optimization is so bad that it "
#          'comparatively makeslook like a perfectly smooth experience.For the '
#          'purposes of this review,was played on both a desktop and laptop, '
#          'with both sharing high-end intel i7 processors. The desktop boasted '
#          'a Nvidia 2070 GTX gpu, and the laptop featured a Nvidia 3070 RTX '
#          'gpu. Despite the game advertising that it only required a minimum '
#          'GPU requirement of a Nvidia 1060, with the Nvidia 3070 RTX being the '
#          'recommended GPU for high-end performance, you can rest assured that '
#          'even with the latter firmly in place, your PC will struggle to '
#          'consistently maintain a stable minimum of 1080p 60fps. After running '
#          'benchtests using a variety of option configurations, including '
#          'enabling and disabling Vsync, it became clear that even if the '
#          'player reduced all graphical settings to their minimum values, and '
#          'ran a 3070 RTX, there was still no way of completely mitigating the '
#          'frame drops, stutter, and other similar issues. The lack of file '
#          'optimization here is likewise absurd. As if offering a retail asking '
#          "price of $69.99 for this mess of a game wasn't absurd on its own, "
#          'the fact that the game requires over 150 GBs of HDD space makes it '
#          'even less desirable.is not worth either your money, or your time. '
#          'Even were it offered for free, perhaps as part of a free weekend '
#          'promotion on Steam, or as one of the rotating weekly free game '
#          'giveaways on the Epic Games Store, it would still be too high a '
#          'price to pay, as the time investment costs far outweigh the doubtful '
#          'pleasure of experiencing what littlehas to offer.',
#  'title': 'Forspoken PC review - "Forspoken should be forgotten"',
#  'top_image': 'https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg',
#  'top_img': 'https://www.hookedgamers.com/images/7017/forspoken/reviews/header_2402_forspoken.jpg',
#  'top_node': <Element section at 0x219072bef40>,
#  'url': 'https://www.hookedgamers.com/pc/forspoken/review/article-2402.html'}

# %%
article.title
# Out:
# 'Forspoken PC review - "Forspoken should be forgotten"'

# %%
article.authors
# Out:
# []

# %%
article.text
# Out:
# "Aims low, lands lower.\n\nAn open world devoid of life...\n\nTechnical difficulties ahead...\n\nFinal Thoughts:\n\nUnder the mire of's many flaws, there is the individual fragments of what could have been a highly compelling, or at least passable, narrative.follows the character of Frey, who grew up with no family, no prospects, and forced to rely on street gangs in order to scratch out a living. After facing the prospect of prison time for her criminal offenses, Frey instead has her sentence commuted by the judge, who gives her one final chance to set things right. However, things go wrong from that point on, and after a series of misadventures, Frey finds herself transported to a magical world, with no clear way home. Everything about Frey's origin story plaintively makes it clear that the player is expected to find her a sympathetic, or even relatable, character. The problem though is that this message definitely wasn't conveyed to whoever was in charge of writing the dialogue.Through both the written dialogue and the voice acting performance, Frey has all the personal likeability of nails on a chalkboard. If you were hoping that, over time, the player might find themselves connecting more with Frey, you probably shouldn't get your hopes up. Similar tomakes the critical mistake of assuming random out-of-context swearing and an abrasive attitude are the two sole factors in a protagonist's personality. And since the player will be hearing quite a bit from Frey over the course of the game, this is no minor issue to overlook.The gameplay mechanics are fairly in line with what one would expect of any other open-world RPG. There are different zones, farmable resources, a variety of enemy types of varying difficulty for you to grind XP and resources from, and of course, story missions for you to progress through. But none of it feels particularly gripping. Even only a few hours in, it's easy to lose interest in what you're doing. This is helped, of course, by the fact that's PC optimization is so bad that it comparatively makeslook like a perfectly smooth experience.For the purposes of this review,was played on both a desktop and laptop, with both sharing high-end intel i7 processors. The desktop boasted a Nvidia 2070 GTX gpu, and the laptop featured a Nvidia 3070 RTX gpu. Despite the game advertising that it only required a minimum GPU requirement of a Nvidia 1060, with the Nvidia 3070 RTX being the recommended GPU for high-end performance, you can rest assured that even with the latter firmly in place, your PC will struggle to consistently maintain a stable minimum of 1080p 60fps. After running benchtests using a variety of option configurations, including enabling and disabling Vsync, it became clear that even if the player reduced all graphical settings to their minimum values, and ran a 3070 RTX, there was still no way of completely mitigating the frame drops, stutter, and other similar issues. The lack of file optimization here is likewise absurd. As if offering a retail asking price of $69.99 for this mess of a game wasn't absurd on its own, the fact that the game requires over 150 GBs of HDD space makes it even less desirable.is not worth either your money, or your time. Even were it offered for free, perhaps as part of a free weekend promotion on Steam, or as one of the rotating weekly free game giveaways on the Epic Games Store, it would still be too high a price to pay, as the time investment costs far outweigh the doubtful pleasure of experiencing what littlehas to offer."

# %%
article.article_html
# Out:
# '<div><h2>Aims low, lands lower.</h2><br>\r\nUnder the mire of <i>Forspoken</i>\'s many flaws, there is the individual fragments of what could have been a highly compelling, or at least passable, narrative. <i>Forspoken</i> follows the character of Frey, who grew up with no family, no prospects, and forced to rely on street gangs in order to scratch out a living. After facing the prospect of prison time for her criminal offenses, Frey instead has her sentence commuted by the judge, who gives her one final chance to set things right. However, things go wrong from that point on, and after a series of misadventures, Frey finds herself transported to a magical world, with no clear way home. Everything about Frey\'s origin story plaintively makes it clear that the player is expected to find her a sympathetic, or even relatable, character. The problem though is that this message definitely wasn\'t conveyed to whoever was in charge of writing the dialogue.<br>\r\n<br>\r\nThrough both the written dialogue and the voice acting performance, Frey has all the personal likeability of nails on a chalkboard. If you were hoping that, over time, the player might find themselves connecting more with Frey, you probably shouldn\'t get your hopes up. Similar to <i>Outriders</i>, <i>Forspoken</i> makes the critical mistake of assuming random out-of-context swearing and an abrasive attitude are the two sole factors in a protagonist\'s personality. And since the player will be hearing quite a bit from Frey over the course of the game, this is no minor issue to overlook.<br>\r\n<br>\r\n <br>\r\n<br>\r\n<h2>An open world devoid of life...</h2><br>\r\nThe gameplay mechanics are fairly in line with what one would expect of any other open-world RPG. There are different zones, farmable resources, a variety of enemy types of varying difficulty for you to grind XP and resources from, and of course, story missions for you to progress through. But none of it feels particularly gripping. Even only a few hours in, it\'s easy to lose interest in what you\'re doing. This is helped, of course, by the fact that <i>Forspoken</i>\'s PC optimization is so bad that it comparatively makes <i>Hogwarts Legacy</i> look like a perfectly smooth experience. <br>\r\n<br>\r\n<h2>Technical difficulties ahead...</h2><br>\r\nFor the purposes of this review, <i>Forspoken</i> was played on both a desktop and laptop, with both sharing high-end intel i7 processors. The desktop boasted a Nvidia 2070 GTX gpu, and the laptop featured a Nvidia 3070 RTX gpu. Despite the game advertising that it only required a minimum GPU requirement of a Nvidia 1060, with the Nvidia 3070 RTX being the recommended GPU for high-end performance, you can rest assured that even with the latter firmly in place, your PC will struggle to consistently maintain a stable minimum of 1080p 60fps. After running benchtests using a variety of option configurations, including enabling and disabling Vsync, it became clear that even if the player reduced all graphical settings to their minimum values, and ran a 3070 RTX, there was still no way of completely mitigating the frame drops, stutter, and other similar issues. The lack of file optimization here is likewise absurd. As if offering a retail asking price of $69.99 for this mess of a game wasn\'t absurd on its own, the fact that the game requires over 150 GBs of HDD space makes it even less desirable. <br>\r\n<br>\r\n<h2>Final Thoughts:</h2><br>\r\n<i>Forspoken</i> is not worth either your money, or your time. Even were it offered for free, perhaps as part of a free weekend promotion on Steam, or as one of the rotating weekly free game giveaways on the Epic Games Store, it would still be too high a price to pay, as the time investment costs far outweigh the doubtful pleasure of experiencing what little <i>Forspoken</i> has to offer.<br>\r\n<br>\r\n<br>\r\n<i>As always, follow us on <a href="https://www.instagram.com/hooked_gamers/" target="new">Instagram</a> for news upd ...

# %% [markdown]
# ### NLP

# %%
# import nltk  # because of a weird error https://github.com/delip/PyTorchNLPBook/issues/14
# nltk.download('punkt')

article.nlp()

# %%
print(article.summary)
# Out:
# However, things go wrong from that point on, and after a series of misadventures, Frey finds herself transported to a magical world, with no clear way home.
# Everything about Frey's origin story plaintively makes it clear that the player is expected to find her a sympathetic, or even relatable, character.
# If you were hoping that, over time, the player might find themselves connecting more with Frey, you probably shouldn't get your hopes up.
# Similar tomakes the critical mistake of assuming random out-of-context swearing and an abrasive attitude are the two sole factors in a protagonist's personality.
# The desktop boasted a Nvidia 2070 GTX gpu, and the laptop featured a Nvidia 3070 RTX gpu.

# %%
article.keywords
# Out:
# ['review',
#  'forspoken',
#  'clear',
#  'player',
#  'gpu',
#  'rtx',
#  'game',
#  'free',
#  'minimum',
#  'nvidia',
#  'course',
#  'forgotten',
#  'pc',
#  'frey']

# %% [markdown]
# # Test several articles

# %%
urls = [
    'https://www.pcinvasion.com/forspoken-pc-review/',
    'https://www.somosxbox.com/analisis-de-forspoken-pc/981286',
    'https://www.gamestar.de/artikel/forspoken-test-review,3389075.html',
    'https://www.pcgamer.com/forspoken-review/',
    'https://xboxera.com/2023/01/25/review-forspoken/',
    'https://www.hookedgamers.com/pc/forspoken/review/article-2402.html'
]

# %%
def parse_article(url: str) -> pd.DataFrame:
    article = Article(url, keep_article_html=True)
    article.download()
    article.parse()
    
    print(f"url:\t\t {url}")
    print(f"title:\t\t {article.title}")
    print(f"authors:\t {article.authors}")
    print(f"language:\t {article.meta_lang}")
    print(f"publish_date:\t {article.publish_date}")
    print(f"text:\t\t {article.text[:200]}")
    print(f"article_html:\t {article.article_html[:200]}")
    print("---------------------------------------------------------------------------------------------------------\n")

# %%
for url in urls:
    parse_article(url)
# Out:
# url:		 https://www.pcinvasion.com/forspoken-pc-review/
# title:		 Forspoken PC review — Magic and mayhem
# authors:	 ['Jason Rodriguez', 'Jason Rodriguez Is A Guides Writer. Most Of His Work Can Be Found On Pc Invasion', 'Around', "Published Articles . He'S Also Written For Ign", 'Gamespot', 'Polygon', 'Techraptor', 'Gameskinny', "More. He'S Also One Of Only Five Games Journalists The Philippines. Just Kidding. There Are Definitely More Around", "But He Doesn'T Know Anyone. Mabuhay"]
# language:	 en
# publish_date:	 2023-01-31 17:00:36+00:00
# text:		 Forspoken is an open-world role-playing game (RPG) from Luminous Productions and Square Enix. I’ve been looking forward to this for quite a while now, as open-world adventures tend to be one of my fav
# article_html:	 <div><p>Forspoken is an <a href="https://store.steampowered.com/app/1680880/Forspoken/" target="_blank" rel="noopener">open-world role-playing game (RPG)</a> from Luminous Productions and Square Enix.
# ---------------------------------------------------------------------------------------------------------
#
# url:		 https://www.somosxbox.com/analisis-de-forspoken-pc/981286
# title:		 Análisis de Forspoken – PC
# authors:	 ['Antonio Horna']
# language:	 es
# publish_date:	 2023-02-03 11:00:15+01:00
# text:		 No pasa muy a menudo que Square-Enix lance al mercado un JRPG de una IP totalmente nueva. La compañía madre de sagas como Final Fantasy o Dragon Quest es posiblemente la primera que se nos viene a la
# article_html:	 <div><p>No pasa muy a menudo que <a href="https://www.somosxbox.com/tag/square-enix">Square-Enix</a> lance al mercado un JRPG de una IP totalmente nueva. La compa&#241;&#237;a madre de sagas como Fina
# ---------------------------------------------------------------------------------------------------------
#
# url:		 https://www.gamestar.de/artikel/forspoken-test-review,3389075.html
# title:		 Forspoken Test: Seit AC Valhalla ließ sich nicht mehr so über eine Open World streiten
# authors:	 []
# language:	 de
# publish_date:	 2023-01-26 09:40:00+01:00
# text:		 Unser Test zu Forspoken ist fertig, wir haben die PC-Version gespielt. Und müssen viel meckern.
#
# Update vom 26. Januar 2023: Zum PC-Release auf Steam konnten wir Forspoken endlich auch abseits der Pla
# article_html:	 <div><p class="caption ">
#
#
# <img src="" width="960" height="540" class="responsive m-b-0 lazyload" alt="Unser Test zu Forspoken ist fertig, wir haben die PC-Version gespielt. Und m&#252;ssen viel meck
# ---------------------------------------------------------------------------------------------------------
#
# url:		 https://www.pcgamer.com/forspoken-review/
# title:		 Forspoken review
# authors:	 ['Mollie Taylor', 'Features Producer', 'Window.Slicecomponents', 'Externalsscriptloaded.Then', 'Window.Reliabledomcontentloaded.Then', 'Var Componentcontainer', 'Document.Queryselector', 'Slice-Container-Authorbio', 'If Componentcontainer', 'Var Data']
# language:	 en
# publish_date:	 2023-01-30 16:47:41+00:00
# text:		 Forspoken occasionally has small sparks of greatness, but then quickly douses itself in fear of ever being anything other than an upsettingly safe open-world RPG.
#
# Why you can trust PC Gamer Our exper
# article_html:	 <div><p>Forspoken occasionally has small sparks of greatness, but then quickly douses itself in fear of ever being anything other than an upsettingly safe open-world RPG.</p><p>Why you can trust PC Ga
# ---------------------------------------------------------------------------------------------------------
#
# url:		 https://xboxera.com/2023/01/25/review-forspoken/
# title:		 Review | Forspoken
# authors:	 ["Jesse 'Doncabesa' Norris", 'Proud Father Of Two', 'Lucky To Have A Wife Far Too Good For Me. I Write A Ton Of Reviews', 'Am A Host On The You Had Me At Halo Podcast', 'Help Fill Out Anywhere I Can For Our Site.']
# language:	 en
# publish_date:	 2023-01-25 00:00:00
# text:		 Forspoken has launched on the Windows Store with full achievements. It’s an action RPG from Square Enix that PlayStation purchased at least two years of exclusivity on, but we’re covering it for our P
# article_html:	 <div><p>Forspoken has launched on the Windows Store with full achievements.&#160; It&#8217;s an action RPG from Square Enix that PlayStation purchased at least two years of exclusivity on, but we&#821
# ---------------------------------------------------------------------------------------------------------
#
# url:		 https://www.hookedgamers.com/pc/forspoken/review/article-2402.html
# title:		 Forspoken PC review - "Forspoken should be forgotten"
# authors:	 []
# language:	 en
# publish_date:	 None
# text:		 Aims low, lands lower.
#
# An open world devoid of life...
#
# Technical difficulties ahead...
#
# Final Thoughts:
#
# Under the mire of's many flaws, there is the individual fragments of what could have been a h
# article_html:	 <div><h2>Aims low, lands lower.</h2><br>
# Under the mire of <i>Forspoken</i>'s many flaws, there is the individual fragments of what could have been a highly compelling, or at least passable, narrativ
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Verdict

# %% [markdown]
# - `title` is mostly fine (it's from \<title\> tag but not exactly)
# - `authors` - not fine but we don't really need it
# - `language` - works fine, extracted from html tag
# - `publish_date` - mostly fine (but in last case - it didn't find it)
# - `text` - sometimes in the wrong order, which is weird, e.g:
#   - conclusion at the beginning (pcgamer review - but it's not shown correctly even in instapaper)
#   - headers before text (hookedgamers review - but this is in `article.html` so we can fix it if we need. idk if order matters)
# also: it would be nice to distinguish between headers and text (not possible currently but this info is in `article.html` so we can add this)
# - NLP - we should ignore it
#
# ✅ Overall, I think for now we can use it (maybe fork the repo and make some changes).

# %% [markdown]
# # Languages

# %%
newspaper.languages()
# Out:
# Your available languages are:
#
# input code		full name
#   ar			  Arabic
#   be			  Belarusian
#   bg			  Bulgarian
#   da			  Danish
#   de			  German
#   el			  Greek
#   en			  English
#   es			  Spanish
#   et			  Estonian
#   fa			  Persian
#   fi			  Finnish
#   fr			  French
#   he			  Hebrew
#   hi			  Hindi
#   hr			  Croatian
#   hu			  Hungarian
#   id			  Indonesian
#   it			  Italian
#   ja			  Japanese
#   ko			  Korean
#   mk			  Macedonian
#   nb			  Norwegian (Bokmål)
#   nl			  Dutch
#   no			  Norwegian
#   pl			  Polish
#   pt			  Portuguese
#   ro			  Romanian
#   ru			  Russian
#   sl			  Slovenian
#   sr			  Serbian
#   sv			  Swedish
#   sw			  Swahili
#   tr			  Turkish
#   uk			  Ukrainian
#   vi			  Vietnamese
#   zh			  Chinese

# %% [markdown]
# # Building a news source

# %% [markdown]
# ❌ This doesn't help us

# %%
url_game = 'https://www.metacritic.com/game/pc/forspoken'
metacritic_game = newspaper.build(url_game)

metacritic_game.size()
# Out:
# 0

# %%
for article in metacritic_game.articles:
    print(article.url)

# %%
for category in metacritic_game.category_urls():
    print(category)
# Out:
# https://www.metacritic.com/game/pc/forspoken
# https://www.metacritic.com
# https://www.metacritic.com/game
# https://www.metacritic.com/tv
# https://www.metacritic.com/features
# https://www.metacritic.com/feature
# https://www.metacritic.com/movie
# https://www.metacritic.com/music
